# %%
def push(message):
    """
    Save current notebook and push whole current dir to origin/master
    
    Param:
        message : str 
            Commit's message
    
    Return:
        None
    """
    assert(len(message.strip())>10)
    import subprocess
    from IPython.display import display, Javascript
    
    cmds = [  "git add .",
              "git commit -m ", 
              "git push"]
    
    # save current notebook
    display(Javascript('IPython.notebook.save_checkpoint();'))
    for cmd in cmds:
        cmd = cmd.split()
        if "commit" in cmd: 
            cmd.append( f"'{message}'") 
        print(" ".join(cmd))
        subprocess.check_output(cmd)
    print("Fini.")

# %% [markdown]
# # 1) numpy

# %%
import numpy as np

# %%
array = np.arange(0,10)

# %%
array.ndim
# Out:
# 1

# %%
array.size
# Out:
# 10

# %%
array.dtype
# Out:
# dtype('int64')

# %% [markdown]
# # 2) conversion d'une liste de liste en array numpy

# %%
matrice = np.asarray([[1,2,3],[4,5,6]])

# %%
matrice.dtype, matrice.ndim
# Out:
# (dtype('int64'), 2)

# %%
matrice.shape
# Out:
# (2, 3)

# %% [markdown]
# # 3) Pandas

# %%
### Nb: si pandas n'est pas installée, installer avec "pip install pandas"
# pip install --upgrade pandas
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /Users/romain/opt/anaconda3/lib/python3.8/site-packages (1.2.4)
# Requirement already satisfied: numpy>=1.16.5 in /Users/romain/opt/anaconda3/lib/python3.8/site-packages (from pandas) (1.19.2)
# Requirement already satisfied: pytz>=2017.3 in /Users/romain/opt/anaconda3/lib/python3.8/site-packages (from pandas) (2020.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/romain/opt/anaconda3/lib/python3.8/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: six>=1.5 in /Users/romain/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)

# %%
push("pour suivre")
# Out:
# git add .
# git commit -m 'pour suivre'
# git push
# Fini.

# %% [markdown]
# ## 3.0) loader la librairie

# %%
import pandas as pd

# %% [markdown]
# #### Regarder les versions d'une librairie

# %%
np.__version__
# Out:
# '1.19.2'

# %%
pd.__version__
# Out:
# '1.2.4'

# %% [markdown]
# ## 3.1) création d'une dataframe à partir d'un dico

# %%
métiers = ["journaliste", "capitaine"]
noms    = ["tintin", "hadock"]
personnages = {"métiers" : métiers, 
               "noms":noms}

# %%
personnages
# Out:
# {'métiers': ['journaliste', 'capitaine'], 'noms': ['tintin', 'hadock']}

# %%
df = pd.DataFrame(personnages)

# %%
df
# Out:
#        métiers    noms
# 0  journaliste  tintin
# 1    capitaine  hadock

# %% [markdown]
# ## 3.2) regardons les attributs

# %%
df.shape
# Out:
# (2, 2)

# %%
df.columns
# Out:
# Index(['métiers', 'noms'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=2, step=1)

# %%
df.index.name

# %% [markdown]
# ## 3.3) nommons les index

# %%
df.columns.name = "hergé"

# %%
df.index.name = "numéro"
df
# Out:
# hergé       métiers    noms
# numéro
# 0       journaliste  tintin
# 1         capitaine  hadock

# %% [markdown]
# ## 3.3 bis) enregistrer sous excel

# %%
df.to_excel("herge.xlsx", index=False)

# %%
# !open herge.xlsx

# %%
df = pd.read_excel("herge.xlsx")

# %%
df
# Out:
#        métiers    noms
# 0  journaliste  tintin
# 1    capitaine  hadock

# %% [markdown]
# ## 3.4) récupérer une colonne

# %%
col_1 = df["métiers"] # récupérer la colonne "métiers"

# %%
type(col_1) # une datframe est composée de Série(s)
# Out:
# pandas.core.series.Series

# %%
col_1
# Out:
# 0    journaliste
# 1      capitaine
# Name: métiers, dtype: object

# %%
col_2 = df["noms"]
col_2
# Out:
# 0    tintin
# 1    hadock
# Name: noms, dtype: object

# %% [markdown]
# ###### on peut récupérer une colonne en s'appuyant sur la liste des colonnes indiquées par l'attribut "columns"

# %%
df.columns[1]
# Out:
# 'noms'

# %%
df[df.columns[0]]
# Out:
# 0    journaliste
# 1      capitaine
# Name: métiers, dtype: object

# %% [markdown]
# ## 3.5) ajout de colonnes

# %%
df["âges"] = [40, 50] # ajout d'une colonne âges
df
# Out:
#        métiers    noms  âges
# 0  journaliste  tintin    40
# 1    capitaine  hadock    50

# %%
df["âges 2"] = [40, None]
df
# Out:
#        métiers    noms  âges  âges 2
# 0  journaliste  tintin    40    40.0
# 1    capitaine  hadock    50     NaN

# %%
### df.index <=> index des lignes => numérotation des lignes (par défaut)
### df.columns <=> index des colonnes => noms des colonnes

# %% [markdown]
# ## 3.6) remplacer la numérotation des lignes par des chaines de caractères arbitraires

# %%
df.index = ["hero", "secondaire"]

# %%
df
# Out:
#                 métiers    noms  âges  âges 2
# hero        journaliste  tintin    40    40.0
# secondaire    capitaine  hadock    50     NaN

# %%
df.index.name = "type de personnage"

# %% [markdown]
# ## 3.7) rajouter des lignes dans une datframe => append + liste de dico

# %%
df2 = df.append([{"métiers" : "savant", "noms" : "tournesol"}])

# %%
df2 = df2.append([{"métiers" : "savant fou", 
                   "noms"    : "tournesol", 
                   "index"   : 1}])

# %%
df2
# Out:
#                 métiers       noms  âges  âges 2  index
# hero        journaliste     tintin  40.0    40.0    NaN
# secondaire    capitaine     hadock  50.0     NaN    NaN
# 0                savant  tournesol   NaN     NaN    NaN
# 0            savant fou  tournesol   NaN     NaN    1.0
# 0            savant fou  tournesol   NaN     NaN    1.0

# %% [markdown]
# #### si on a des nuls dans la df, on peut les remplacer par une valeur par défaut, par exemple ici 0, avec : fillna

# %%
valeur_par_défaut = "inconnu"
df2.fillna(valeur_par_défaut)
# Out:
#                 métiers       noms     âges   âges 2    index
# hero        journaliste     tintin     40.0     40.0  inconnu
# secondaire    capitaine     hadock     50.0  inconnu  inconnu
# 0                savant  tournesol  inconnu  inconnu  inconnu
# 0            savant fou  tournesol  inconnu  inconnu      1.0
# 0            savant fou  tournesol  inconnu  inconnu      1.0

# %% [markdown]
# ## 3.8) transformer l'index en index de dates

# %%
index_de_dates = pd.date_range(start = "01/01/1930" , 
                               end   = "31/12/1940" ,
                               freq  = "Y"          )

# %%
index_de_dates
# Out:
# DatetimeIndex(['1930-12-31', '1931-12-31', '1932-12-31', '1933-12-31',
#                '1934-12-31', '1935-12-31', '1936-12-31', '1937-12-31',
#                '1938-12-31', '1939-12-31', '1940-12-31'],
#               dtype='datetime64[ns]', freq='A-DEC')

# %%
df2.index = index_de_dates[:len(df2.index)]

# %%
df2
# Out:
#                 métiers       noms  âges  âges 2  index
# 1930-12-31  journaliste     tintin  40.0    40.0    NaN
# 1931-12-31    capitaine     hadock  50.0     NaN    NaN
# 1932-12-31       savant  tournesol   NaN     NaN    NaN
# 1933-12-31   savant fou  tournesol   NaN     NaN    1.0
# 1934-12-31   savant fou  tournesol   NaN     NaN    1.0

# %% [markdown]
# #### Ajout d'une df sous une df : méthode append

# %%
df2.append(df2).loc["1932"]
# Out:
#            métiers       noms  âges  âges 2  index
# 1932-12-31  savant  tournesol   NaN     NaN    NaN
# 1932-12-31  savant  tournesol   NaN     NaN    NaN

# %% [markdown]
# ## 3.9) Rechercher les lignes de la dataframe qui sont dans une année donnée

# %% [markdown]
# ### Recherche sur une annee

# %%
annee_voulue = "1932"

# %%
df2.loc[annee_voulue]
# Out:
#            métiers       noms  âges  âges 2  index
# 1932-12-31  savant  tournesol   NaN     NaN    NaN

# %% [markdown]
# ### Recherche sur une annee et un mois

# %%
mois_voulu = "1931-12"

# %%
df2.loc[mois_voulu]
# Out:
#               métiers    noms  âges  âges 2  index
# 1931-12-31  capitaine  hadock  50.0     NaN    NaN

# %%
df3 = df2.append(df2.loc[mois_voulu])

# %%
df3.loc[mois_voulu]
# Out:
#               métiers    noms  âges  âges 2  index
# 1931-12-31  capitaine  hadock  50.0     NaN    NaN
# 1931-12-31  capitaine  hadock  50.0     NaN    NaN

# %%
df3.loc[mois_voulu]
# Out:
#               métiers    noms  âges  âges 2  index
# 1931-12-31  capitaine  hadock  50.0     NaN    NaN
# 1931-12-31  capitaine  hadock  50.0     NaN    NaN

# %%
push(" pour suivre")
# Out:
# git add .
# git commit -m ' pour suivre'
# git push
# Fini.

# %% [markdown]
# ## 3.10) apply map : application d'une formule / fonction sur chaque case de la matrice (élément par élément)

# %%
df["âges2"] = [1,2]

# %%
int, str
# Out:
# (int, str)

# %%
type("coucou") == str
# Out:
# True

# %% [markdown]
# ##### Type des éléments de la df

# %%
df.applymap(lambda x: type(x))
# Out:
#                           métiers           noms           âges  \
# type de personnage
# hero                <class 'str'>  <class 'str'>  <class 'int'>
# secondaire          <class 'str'>  <class 'str'>  <class 'int'>
#
#                              âges 2          âges2
# type de personnage
# hero                <class 'float'>  <class 'int'>
# secondaire          <class 'float'>  <class 'int'>

# %%
df.applymap(type)
# Out:
#                           métiers           noms           âges  \
# type de personnage
# hero                <class 'str'>  <class 'str'>  <class 'int'>
# secondaire          <class 'str'>  <class 'str'>  <class 'int'>
#
#                              âges 2          âges2
# type de personnage
# hero                <class 'float'>  <class 'int'>
# secondaire          <class 'float'>  <class 'int'>

# %% [markdown]
# ####  structure  [ x if condition else y  ]

# %%
df.applymap(lambda x: 2*x if type(x)==int else x)
# Out:
#                         métiers    noms  âges  âges 2  âges2
# type de personnage
# hero                journaliste  tintin    80    40.0      2
# secondaire            capitaine  hadock   100     NaN      4

# %% [markdown]
# #### Concaténation de deux structures  [ x if condition else y  ] =>  [ x if condition else  y  if condition else z  ]

# %%
df.applymap(lambda x: 2*x if type(x)==int else x if type(x)==str else -1)
# Out:
#                         métiers    noms  âges  âges 2  âges2
# type de personnage
# hero                journaliste  tintin    80      -1      2
# secondaire            capitaine  hadock   100      -1      4

# %% [markdown]
# ### Applymap attend une fonction avec un paramètre

# %%
def manage_data(data):
    if type(data)==type(1):
        return 2*data 
    if not data==data: # teste si la valeur est indéfine, 
                        # une valeur indéfinie c'est une valeu qui n'est pas égale à elle même
                        # ainsi on en déduit qu'elle est indéfinie, comme NaN
        return "indéfini"
        
    return str(data)

# %%
df.applymap(manage_data)
# Out:
#                         métiers    noms  âges    âges 2  âges2
# type de personnage
# hero                journaliste  tintin    80      40.0      2
# secondaire            capitaine  hadock   100  indéfini      4

# %% [markdown]
# # A) one-line sur un if / else

# %%
age = 30

# %%
x = "adulte" if 18 < age else "mineur"
x
# Out:
# 'adulte'

# %% [markdown]
# ## 3.11) réordonner les colonnes

# %%
df["prenom"] = ["a", "b"]

# %%
nouvel_ordre_des_colonnes =  ['métiers','prenom', 'noms', 'âges', 'âges 2', 'âges2']
df = df[nouvel_ordre_des_colonnes]

# %% [markdown]
# ## 3.12) choisir un sous ensemble de colonnes

# %%
colonnes_a_afficher  = ['métiers','prenom',]
df[colonnes_a_afficher]
# Out:
#                         métiers prenom
# type de personnage
# hero                journaliste      a
# secondaire            capitaine      b

# %%
push("pour suivre")
# Out:
# git add .
# git commit -m 'pour suivre'
# git push
# Fini.

# %% [markdown]
# # B) sauvegarde d'objets python sur le disque => pickle
# Quand vous avez un objet, du type dataframe, ou de n'importe quel type , il a des attributs, des méthodes, un état... si vous fermez votre programme, vous allez perdre vos objets. Hors ça peut être intéressant de les conserver d'une session à l'autre, notamment si c'est le résultat de plein de calculs.
# Vous pourriez les enregistrer dans une base de donnée, ou dans un csv (mais vous perdriez sans doute des choses), donc python vous permet de les enregistrer sur disque, pour les reloader tel quel, via le module pickle.
# Pickle est intégré à Pandas, et vous permet donc d'enregistrer des DF non plus sous format excel ou csv, mais directement en format objet.

# %% [markdown]
# ##### Démo:  en enregistrant dans excel, on perd le nom de l'index des colonnes

# %%
df.columns.name = "test"
df
# Out:
# test                    métiers prenom    noms  âges  âges 2  âges2
# type de personnage
# hero                journaliste      a  tintin    40    40.0      1
# secondaire            capitaine      b  hadock    50     NaN      2

# %%
df.to_excel("test.xlsx")

# %%
df_test = pd.read_excel("test.xlsx")

# %%
df_test
# Out:
#   type de personnage      métiers prenom    noms  âges  âges 2  âges2
# 0               hero  journaliste      a  tintin    40    40.0      1
# 1         secondaire    capitaine      b  hadock    50     NaN      2

# %% [markdown]
# #### Démo : avec pickle je conserve le nom de l'index des colonnes

# %%
df.to_pickle("test.pkl")

# %%
df_pickle = pd.read_pickle("test.pkl")

# %%
df_pickle
# Out:
# test                    métiers prenom    noms  âges  âges 2  âges2
# type de personnage
# hero                journaliste      a  tintin    40    40.0      1
# secondaire            capitaine      b  hadock    50     NaN      2

# %% [markdown]
# ### Attention : pickle n'est pas garanti de fonctionner de la même manière d'une version de python à l'autre (pas de rétro-compatibilité) => ne pas s'appuyer sur pickle comme médium d'échange d'objet (trop sensible à la version de python)

# %% [markdown]
# # 4) Chargement de la base csv cycliste

# %% [markdown]
# ## le module pandas a une méthode read_csv

# %%
url_vers_csv = "https://raw.githubusercontent.com/romainjouin/formation_python/master/cyclistes.csv"
cyclistes = pd.read_csv(url_vers_csv)

# %% [markdown]
# ##### Head pour afficher n premières lignes

# %%
cyclistes.head(2)
# Out:
#     id sexe  sportivite  age  sur_velo
# 0  101    F   -0.285718   66      True
# 1  102    H    2.219441   37      True

# %% [markdown]
# #### Describe pour quelques statistiques descriptives

# %%
cyclistes.describe()
# Out:
#                 id   sportivite          age
# count  1000.000000  1000.000000  1000.000000
# mean    600.500000     2.022684    48.341000
# std     288.819436     1.956014    19.994712
# min     101.000000    -3.797412    15.000000
# 25%     350.750000     0.736858    31.000000
# 50%     600.500000     1.963103    46.000000
# 75%     850.250000     3.320488    66.000000
# max    1100.000000     7.325543    84.000000

# %% [markdown]
# ## 4.1) filtrer sur les femmes

# %%
mask = cyclistes.sexe == "F" # création d'un masque selon une condition
type(mask)
# Out:
# pandas.core.series.Series

# %%
cyclistes[mask] # application du mask
# Out:
#        id sexe  sportivite  age  sur_velo
# 0     101    F   -0.285718   66      True
# 2     103    F    2.637251   49      True
# 3     104    F    1.413551   33      True
# 5     106    F    2.850941   22      True
# 7     108    F    1.838594   52      True
# ..    ...  ...         ...  ...       ...
# 989  1090    F    5.394923   24     False
# 990  1091    F    0.999379   32      True
# 992  1093    F    3.431615   46     False
# 998  1099    F    0.205798   77      True
# 999  1100    F    6.929330   70      True
#
# [506 rows x 5 columns]

# %%
push("pour suivre")
# Out:
# git add .
# git commit -m 'pour suivre'
# git push
# Fini.

# %% [markdown]
# ## 4.2) fonction count, min et max

# %%
adultes = 18 < cyclistes.age
mineurs = cyclistes.age < 18

# %%
nb_d_adultes = cyclistes[adultes]["id"].count()

# %%
nb_de_mineurs =  cyclistes[mineurs]["id"].count()

# %%
pctage_adults = nb_d_adultes / (nb_d_adultes+nb_de_mineurs)

# %%
f"il y a {nb_d_adultes} adultes et {nb_de_mineurs} mineurs ({pctage_adults*100:.2f}% d'adultes)"
# Out:
# "il y a 949 adultes et 36 mineurs (96.35% d'adultes)"

# %% [markdown]
# ### Min et max

# %%
cyclistes.age.min()
# Out:
# 15

# %%
cyclistes.age.max()
# Out:
# 84

# %% [markdown]
# ## 4.3) profiter d'avoir fait un mask pour enrichir notre dataset => feature_engineering

# %%
cyclistes["est_adulte"] = adultes # adultes est le masque créé ci dessus (en 4.2)
cyclistes["est_mineur"] = mineurs # mineurs est le masque créé ci dessus (en 4.2)

# %%
cyclistes.sample(10)
# Out:
#       id sexe  sportivite  age  sur_velo  est_adulte  est_mineur
# 625  726    F    1.959117   31     False        True       False
# 895  996    F    4.126200   51      True        True       False
# 96   197    F   -2.331027   77      True        True       False
# 420  521    H    3.310954   66      True        True       False
# 301  402    F    2.510636   26     False        True       False
# 276  377    H    3.943127   44      True        True       False
# 340  441    H    0.758182   48      True        True       False
# 710  811    F    1.796164   78      True        True       False
# 892  993    H    2.081240   78     False        True       False
# 161  262    H    4.543190   52      True        True       False

# %% [markdown]
# ## 4.4) moyenne des âges des adultes et des mineurs

# %%
age_moyen_des_cyclistes = cyclistes["age"].mean()
age_moyen_des_cyclistes
# Out:
# 48.341

# %%
moyenne_des_ages_des_mineurs = cyclistes[cyclistes.est_mineur]["age"].mean()
moyenne_des_ages_des_mineurs
# Out:
# 16.055555555555557

# %%
moyenne_des_ages_des_adultes = cyclistes[cyclistes.est_adulte]["age"].mean()
moyenne_des_ages_des_adultes
# Out:
# 50.04531085353003

# %%
cyclistes.groupby(["est_adulte"])["age"].mean()
# Out:
# est_adulte
# False    16.627451
# True     50.045311
# Name: age, dtype: float64

# %% [markdown]
# ## Fonction magique jupyter => %matplotlib inline
# => permet d'afficher les graphs matplotlib dans le notebook

# %%
# %matplotlib inline

# %% [markdown]
# # 5) faire des graphs avec pandas

# %% [markdown]
# ## 5.1) fonction "plot" de base => fait des lignes entre chaque point

# %%
cyclistes.age.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 5.2) fonction "plot" en histogramme => regroupe les âges dans 10 (par défaut) catégories ,
# et synthètise l'information  du nombre d'individu ayant l'âge de chaque catégorie

# %%
cyclistes.age.describe()
# Out:
# count    1000.000000
# mean       48.341000
# std        19.994712
# min        15.000000
# 25%        31.000000
# 50%        46.000000
# 75%        66.000000
# max        84.000000
# Name: age, dtype: float64

# %%
cyclistes.age.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ## 5.3) scatter plot

# %%
cyclistes.columns
# Out:
# Index(['id', 'sexe', 'sportivite', 'age', 'sur_velo', 'est_adulte',
#        'est_mineur'],
#       dtype='object')

# %%
cyclistes.plot.scatter(x="age", y="sportivite")
# Out:
# <AxesSubplot:xlabel='age', ylabel='sportivite'>

# %% [markdown]
# ## 5.4) afin de rajouter une perception visuelle j'ajoute une couleur par point
# => du vert pour les adultes, et de l'orange pour les mineurs

# %%
# on rajoute une colonne
cyclistes["couleur_pour_adulte"] = "green"

# %%
cyclistes["couleur_pour_adulte"][mineurs] = "orange"
# Out:
# <ipython-input-162-ffe81c6f9c56>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cyclistes["couleur_pour_adulte"][mineurs] = "orange"

# %%
# on utilise le paramètre "c" qui prendra une colonne pour trouver la couleur à associer à chaque point
cyclistes.plot.scatter(x="age", y="sportivite", c="couleur_pour_adulte")
# Out:
# <AxesSubplot:xlabel='age', ylabel='sportivite'>

# %% [markdown]
# # 6) Pour info : sur une colonne on peut faire un "value_count" => qui nous renvoie le nombre d'occurence de chaque valeur

# %% [markdown]
# #### Le value count ne compte pas les nuls par défaut

# %%
cyclistes["couleur_pour_adulte"].value_counts(dropna=False)
# Out:
# green     964
# orange     36
# Name: couleur_pour_adulte, dtype: int64

# %%
serie = cyclistes["couleur_pour_adulte"]

# %% [markdown]
# ##### L'option "normalize" = True nous donne les pourcentages de présence de chaque valeur

# %%
serie.value_counts(dropna=False, normalize=True)
# Out:
# green     0.964
# orange    0.036
# Name: couleur_pour_adulte, dtype: float64

# %%
nb_de_personnes_ayant_un_age_donné = cyclistes["age"].value_counts()#.plot.scatter()

# %%
nb_de_personnes_ayant_un_age_donné
# Out:
# 26    28
# 46    25
# 43    23
# 35    22
# 19    22
#       ..
# 24     9
# 70     8
# 64     8
# 62     6
# 50     5
# Name: age, Length: 70, dtype: int64

# %% [markdown]
# ## 6.1) reset_index pour transformer le value_count en dataframe

# %%
nb_de_personnes_ayant_un_age_donné.reset_index()
# Out:
#     index  age
# 0      26   28
# 1      46   25
# 2      43   23
# 3      35   22
# 4      19   22
# ..    ...  ...
# 65     24    9
# 66     70    8
# 67     64    8
# 68     62    6
# 69     50    5
#
# [70 rows x 2 columns]

# %%
df_nb_personne_par_age = nb_de_personnes_ayant_un_age_donné.reset_index()

# %% [markdown]
# ## 6.2) renommage des colonnes

# %%
df_nb_personne_par_age.columns = [ 'age', 'Nb_de_personnes',]

# %% [markdown]
# ## 6.3) scatter plot

# %%
df_nb_personne_par_age.plot.scatter(x="age", y="Nb_de_personnes")
# Out:
# <AxesSubplot:xlabel='age', ylabel='Nb_de_personnes'>

# %%
push("End of day 2")
# Out:
# git add .
# git commit -m 'End of day 2'
# git push
# Fini.
